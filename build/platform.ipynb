# %%
# %load_ext autoreload
# %autoreload 2

# %%
import altair

altair.platform.import_globals_notebook(globals())
# Out:
# base_module = altair
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = platform.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/altair/build/platform.ipynb.assets/
