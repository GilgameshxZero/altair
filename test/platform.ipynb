# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777751585.060646  527560 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777751587.269511  527560 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = platform.ipynb
# ASSET_PATH = /home/gilgamesh/main.syncthing/altair/test/platform.ipynb.asset/
# torch: []
# E0000 00:00:1777751592.749145  527560 cuda_executor.cc:1737] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# ...
