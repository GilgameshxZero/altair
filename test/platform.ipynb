# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = platform.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/altair/test/platform.ipynb.assets/
# Loaded `/home/gilgamesh/main.syncthing/altair/.env`.
# torch: []
# tf:
# jax: [CpuDevice(id=0)]
