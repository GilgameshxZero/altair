# %%
# %load_ext autoreload
# %autoreload 2

# %%
import altair

altair.platform.import_globals_notebook(globals())
# Out:
# base_module = altair
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 38.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/altair/project_euler/38.ipynb.assets/

# %%
C_SEGS = [1, 3, 9]
