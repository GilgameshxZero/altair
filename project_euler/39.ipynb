# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utulek

utulek.platform.import_globals_notebook(globals())
# Out:
# base_module = utulek
# IS_NOTEBOOK_KERNEL_CODE = True
# NOTEBOOK_NAME = 39.ipynb
# ASSETS_PATH = /home/gilgamesh/main.syncthing/altair/project_euler/39.ipynb.assets/
# torch: []
# tf:
# jax: [CpuDevice(id=0)]

# %%
tris = {}
for i in range(1, 1001):
	for j in range(i, 1001):
		k = math.floor(math.sqrt(i**2 + j**2))
		p = i + j + k
		if i**2 + j**2 == k**2 and p <= 1000:
			if p not in tris:
				tris[p] = set()
			tris[p].update(((i, j, k), ))
tris[120]
# Out:
# {(20, 48, 52), (24, 45, 51), (30, 40, 50)}

# %%
ts = sorted(tris.values(), key=lambda value: len(value))
ts[-1]
# Out:
# {(40, 399, 401),
#  (56, 390, 394),
#  (105, 360, 375),
#  (120, 350, 370),
#  (140, 336, 364),
#  (168, 315, 357),
#  (210, 280, 350),
#  (240, 252, 348)}
